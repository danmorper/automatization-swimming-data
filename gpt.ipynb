# %%
import pandas as pd

# %%
file_paths = ['csvs/ResultList_25.csv', 'csvs/ResultList_26.csv', 
              'csvs/ResultList_27.csv', 'csvs/ResultList_46.csv']
dataframes = [pd.read_csv(file) for file in file_paths]
print(dataframes)
# Concatenate the datasets into one dataframe
df = pd.concat(dataframes)

# Filter for '100m Mariposa' events
df_100_libre = df[df['style'] == 'libre']
print(df_100_libre)
# Out:
# [  first_surname second_surname     name                          team  \
# 0     rodriguez         castro   victor  11C.D.N. Ciudad De Algeciras
# 1        molina          nuñez   victor           11C.N. San Fernando
# 2     rodriguez         piñero  antonio           11C.N. San Fernando
# 3        virues           alba    pablo           11C.N. San Fernando
# 4       rambouk         larrud    imran  12C.D.N. Ciudad De Algeciras
#
#   race_time gender  distance    style category        date event_time
# 0   2:41.21   masc       200  estilos   alevin  2023-11-04   16:15:00
# 1   2:58.52   masc       200  estilos   alevin  2023-11-04   16:15:00
# 2   2:58.53   masc       200  estilos   alevin  2023-11-04   16:15:00
# 3   3:09.83   masc       200  estilos   alevin  2023-11-04   16:15:00
# 4   3:19.27   masc       200  estilos   alevin  2023-11-04   16:15:00  ,   first_surname second_surname     name                          team  \
# ...
